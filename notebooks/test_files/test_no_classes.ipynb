# %%
import os
import sys
import importlib

script_dir = '/mnt/c/Users/kevin/OneDrive/2-code/1-Research_projects/1-project-categorical-MMN/notebooks'
src_dir = os.path.join(script_dir, '..', 'src')
sys.path.append(src_dir)
import parameters as params
# import classes as cl
import initialization as init

import matplotlib.pyplot as plt

# %%
init.create_internal_connectivity(init.Dict_Weights, **params.PARAMS_ALL)

# %%
plt.plot(init.Dict_Weights['W_pc_to_pv'])
plt.title("Weights")
# Out:
# Text(0.5, 1.0, 'Weights')
